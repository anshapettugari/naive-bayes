# %%
# !pip install joblib
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
sdtr=pd.read_csv("SalaryData_Train.csv")
sdtr
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
sdtr["workclass"]=label_encoder.fit_transform(sdtr["workclass"])
sdtr["education"]=label_encoder.fit_transform(sdtr["education"])
sdtr["maritalstatus"]=label_encoder.fit_transform(sdtr["maritalstatus"])
sdtr["occupation"]=label_encoder.fit_transform(sdtr["occupation"])
sdtr["relationship"]=label_encoder.fit_transform(sdtr["relationship"])
sdtr["race"]=label_encoder.fit_transform(sdtr["race"])
sdtr["sex"]=label_encoder.fit_transform(sdtr["sex"])

sdtr["native"]=label_encoder.fit_transform(sdtr["native"])

sdtr["Salary"]=label_encoder.fit_transform(sdtr["Salary"])
sdtr
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
x=sdtr.iloc[:,0:13]
x
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
y=sdtr.iloc[:,13]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30156    0
# 30157    1
# 30158    0
# 30159    0
# 30160    1
# Name: Salary, Length: 30161, dtype: int32

# %%
sdtes=pd.read_csv("SalaryData_Test.csv")
sdtes["workclass"]=label_encoder.fit_transform(sdtes["workclass"])
sdtes["education"]=label_encoder.fit_transform(sdtes["education"])
sdtes["maritalstatus"]=label_encoder.fit_transform(sdtes["maritalstatus"])
sdtes["occupation"]=label_encoder.fit_transform(sdtes["occupation"])
sdtes["relationship"]=label_encoder.fit_transform(sdtes["relationship"])
sdtes["race"]=label_encoder.fit_transform(sdtes["race"])
sdtes["sex"]=label_encoder.fit_transform(sdtes["sex"])

sdtes["native"]=label_encoder.fit_transform(sdtes["native"])

sdtes["Salary"]=label_encoder.fit_transform(sdtes["Salary"])
sdtes
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
a=sdtes.iloc[:,0:13]
a
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
b=sdtes.iloc[:,13]
b
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 15055    0
# 15056    0
# 15057    0
# 15058    0
# 15059    1
# Name: Salary, Length: 15060, dtype: int32

# %%
clf = MultinomialNB()
clf.fit(x,y)
# Out:
# MultinomialNB()

# %%
clf.score(x,y)
# Out:
# 0.7729186698053778

# %%
y_pred = clf.predict(x)
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.86     22653
#            1       0.63      0.21      0.32      7508
#
#     accuracy                           0.77     30161
#    macro avg       0.71      0.59      0.59     30161
# weighted avg       0.75      0.77      0.73     30161
